# %% [markdown]
# # Interactive Stock Analysis
# The goal of this project is to provide code that will fetch data from finance site and, with the use of python code, parse through the data and re-format in a way that is easier to understand.

# %% [markdown]
# Importing Python packages

# %%
#Import pandas for functions and datareading
#Import MatplotLib for plotting
from pandas_datareader import data
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Function to provide financial data when called

# %%
def readmydata(tickers, start_date, end_date):
    financial_data = data.DataReader(tickers, 'yahoo', start_date, end_date)
    df = pd.DataFrame(financial_data)
    df.columns = df.columns
    output = df.stack(level=-1)
    return output

# %% [markdown]
# Function takes as input dataframe and picks columns

# %%
def pickmydata(data_pack, attributes, num_days):
    #Getting requested columns
    col = data_pack[attributes]
    col.head()
    
    #data_pack (tickers) = 
    #Statistics for requested column
    output = data_pack[attributes].describe()
    
    #for x in symbols
    mytickers = data_pack.index.get_level_values('Symbols')
    mytickers = mytickers.unique()
    
    for x in mytickers: 
        #Object series indexed by date
        data_ticker = col.loc[:, mytickers]
        
        #20-day moving average
        short_rolling_tickers = data_ticker.rolling(window = num_days).mean()

        #Plot
        fig, ax = plt.subplots(figsize=(16,9))
        ax.plot(data_ticker.index, data_ticker, label=data_ticker)
        ax.plot(short_rolling_tickers.index, short_rolling_tickers, label= num_days + 'days rolling')
        ax.set_xlabel('Date')
        ax.set_ylabel(attributes + ' Price ($)')
        ax.legend()
    
    return output

# %% [markdown]
# Calling table function

# %%
data_pack = readmydata(tickers=['AAPL', 'CVX'], start_date='2022-03-01', end_date='2022-06-05')
data_pack.head()
# Out:
# Attributes           Adj Close       Close        High         Low  \
# Date       Symbols
# 2022-03-01 AAPL     162.960571  163.199997  166.600006  161.970001
#            CVX      148.498352  149.720001  149.960007  144.699997
# 2022-03-02 AAPL     166.315643  166.559998  167.360001  162.949997
#            CVX      152.882294  154.139999  155.750000  150.050003
# 2022-03-03 AAPL     165.986115  166.229996  168.910004  165.550003
#
# Attributes                Open      Volume
# Date       Symbols
# 2022-03-01 AAPL     164.699997  83474400.0
#            CVX      145.009995  31159900.0
# 2022-03-02 AAPL     164.389999  79724800.0
#            CVX      150.199997  31329500.0
# 2022-03-03 AAPL     168.470001  76678400.0

# %% [markdown]
# Calling plot function

# %%
pickmydata(data_pack, "Close", 30)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axis.py:1506, in Axis.convert_units(self, x)
#    1505 try:
# -> 1506     ret = self.converter.convert(x, self.units, self)
#    1507 except Exception as e:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\dates.py:1920, in _SwitchableDateConverter.convert(self, *args, **kwargs)
#    1919 def convert(self, *args, **kwargs):
# -> 1920     return self._get_converter().convert(*args, **kwargs)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\dates.py:1849, in DateConverter.convert(value, unit, axis)
#    1843 """
#    1844 If *value* is not already a number or sequence of numbers, convert it
#    1845 with `date2num`.
#    1846
#    1847 The *unit* and *axis* arguments are not used.
#    1848 """
# -> 1849 return date2num(value)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\dates.py:447, in date2num(d)
#     446         d = np.asarray(d)
# --> 447     d = d.astype('datetime64[us]')
#     449 d = _dt64_to_ordinalf(d)
#
# ValueError: Could not convert object to NumPy datetime
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# Input In [38], in <cell line: 1>()
# ----> 1 pickmydata(data_pack, "Close", 30)
#
# Input In [36], in pickmydata(data_pack, attributes, num_days)
#      21 #Plot
#      22 fig, ax = plt.subplots(figsize=(16,9))
# ---> 23 ax.plot(data_ticker.index, data_ticker, label=data_ticker)
#      24 ax.plot(short_rolling_tickers.index, short_rolling_tickers, label= num_days + 'days rolling')
#      25 ax.set_xlabel('Date')
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:1634, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1632 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633 for line in lines:
# -> 1634     self.add_line(line)
#    1635 self._request_autoscale_view(scalex=scalex, scaley=scaley)
#    1636 return lines
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:2283, in _AxesBase.add_line(self, line)
#    2280 if line.get_clip_path() is None:
#    2281     line.set_clip_path(self.patch)
# -> 2283 self._update_line_limits(line)
#    2284 if not line.get_label():
#    2285     line.set_label(f'_child{len(self._children)}')
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:2306, in _AxesBase._update_line_limits(self, line)
#    2302 def _update_line_limits(self, line):
#    2303     """
#    2304     Figures out the data limit of the given line, updating self.dataLim.
#    2305     """
# -> 2306     path = line.get_path()
#    2307     if path.vertices.size == 0:
#    2308         return
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\lines.py:999, in Line2D.get_path(self)
#     997 """Return the `~matplotlib.path.Path` associated with this line."""
#     998 if self._invalidy or self._invalidx:
# --> 999     self.recache()
#    1000 return self._path
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\lines.py:651, in Line2D.recache(self, always)
#     649 def recache(self, always=False):
#     650     if always or self._invalidx:
# --> 651         xconv = self.convert_xunits(self._xorig)
#     652         x = _to_unmasked_float_array(xconv).ravel()
#     653     else:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\artist.py:252, in Artist.convert_xunits(self, x)
#     250 if ax is None or ax.xaxis is None:
#     251     return x
# --> 252 return ax.xaxis.convert_units(x)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axis.py:1508, in Axis.convert_units(self, x)
#    1506     ret = self.converter.convert(x, self.units, self)
#    1507 except Exception as e:
# -> 1508     raise munits.ConversionError('Failed to convert value(s) to axis '
#    1509                                  f'units: {x!r}') from e
#    1510 return ret
#
# ConversionError: Failed to convert value(s) to axis units: array([(Timestamp('2022-03-01 00:00:00'), 'AAPL'),
#        (Timestamp('2022-03-01 00:00:00'), 'CVX'),
#        (Timestamp('2022-03-02 00:00:00'), 'AAPL'),
#        (Timestamp('2022-03-02 00:00:00'), 'CVX'),
#        (Timestamp('2022-03-03 00:00:00'), 'AAPL'),
#        (Timestamp('2022-03-03 00:00:00'), 'CVX'),
#        (Timestamp('2022-03-04 00:00:00'), 'AAPL'),
#        (Timestamp('2022-03-04 00:00:00'), 'CVX'),
#        (Timestamp('2022-03-07 00:00:00'), 'AAPL'),
#        (Timestamp('2022-03-07 00:00:00'), 'CVX'),
#        (Timestamp('2022-03-08 00:00:00'), 'AAPL'),
#        (Timestamp('2022-03-08 00:00:00'), 'CVX'),
#        (Timestamp('2022-03-09 00:00:00'), 'AAPL'),
#        (Timestamp('2022-03-09 00:00:00'), 'CVX'),
#        (Timestamp('2022-03-10 00:00:00'), 'AAPL'),
#        (Timestamp('2022-03-10 00:00:00'), 'CVX'),
#        (Timestamp('2022-03-11 00:00:00'), 'AAPL'),
#        (Timestamp('2022-03-11 00:00:00'), 'CVX'),
#        (Timestamp('2022-03-14 00:00:00'), 'AAPL'),
#        (Timestamp('2022-03-14 00:00:00'), 'CVX'),
#        (Timestamp('2022-03-15 00:00:00'), 'AAPL'),
#        (Timestamp('2022-03-15 00:00:00'), 'CVX'),
#        (Timestamp('2022-03-16 00:00:00'), 'AAPL'),
#        (Timestamp('2022-03-16 00:00:00'), 'CVX'),
#        (Timestamp('2022-03-17 00:00:00'), 'AAPL'),
#        (Timestamp('2022-03-17 00:00:00'), 'CVX'),
#        (Timestamp('2022-03-18 00:00:00'), 'AAPL'),
#        (Timestamp('2022-03-18 00:00:00'), 'CVX'),
#        (Timestamp('2022-03-21 00:00:00'), 'AAPL'),
#        (Timestamp('2022-03-21 00:00:00'), 'CVX'),
#        (Timestamp('2022-03-22 00:00:00'), 'AAPL'),
#        (Timestamp('2022-03-22 00:00:00'), 'CVX'),
#        (Timestamp('2022-03-23 00:00:00'), 'AAPL'),
#        (Timestamp('2022-03-23 00:00:00'), 'CVX'),
#        (Timestamp('2022-03-24 00:00:00'), 'AAPL'),
#        (Timestamp('2022-03-24 00:00:00'), 'CVX'),
#        (Timestamp('2022-03-25 00:00:00'), 'AAPL'),
#        (Timestamp('2022-03-25 00:00:00'), 'CVX'),
#        (Timestamp('2022-03-28 00:00:00'), 'AAPL'),
#        (Timestamp('2022-03-28 00:00:00'), 'CVX'),
#        (Timestamp('2022-03-29 00:00:00'), 'AAPL'),
#        (Timestamp('2022-03-29 00:00:00'), 'CVX'),
#        (Timestamp('2022-03-30 00:00:00'), 'AAPL'),
#        (Timestamp('2022-03-30 00:00:00'), 'CVX'),
#        (Timestamp('2022-03-31 00:00:00'), 'AAPL'),
#        (Timestamp('2022-03-31 00:00:00'), 'CVX'),
#        (Timestamp('2022-04-01 00:00:00'), 'AAPL'),
#        (Timestamp('2022-04-01 00:00:00'), 'CVX'),
#        (Timestamp('2022-04-04 00:00:00'), 'AAPL'),
#        (Timestamp('2022-04-04 00:00:00'), 'CVX'),
#        (Timestamp('2022-04-05 00:00:00'), 'AAPL'),
#        (Timestamp('2022-04-05 00:00:00'), 'CVX'),
#        (Timestamp('2022-04-06 00:00:00'), 'AAPL'),
#        (Timestamp('2022-04-06 00:00:00'), 'CVX'),
#        (Timestamp('2022-04-07 00:00:00'), 'AAPL'),
#        (Timestamp('2022-04-07 00:00:00'), 'CVX'),
#        (Timestamp('2022-04-08 00:00:00'), 'AAPL'),
#        (Timestamp('2022-04-08 00:00:00'), 'CVX'),
#        (Timestamp('2022-04-11 00:00:00'), 'AAPL'),
#        (Timestamp('2022-04-11 00:00:00'), 'CVX'),
#        (Timestamp('2022-04-12 00:00:00'), 'AAPL'),
#        (Timestamp('2022-04-12 00:00:00'), 'CVX'),
#        (Timestamp('2022-04-13 00:00:00'), 'AAPL'),
#        (Timestamp('2022-04-13 00:00:00'), 'CVX'),
#        (Timestamp('2022-04-14 00:00:00'), 'AAPL'),
#        (Timestamp('2022-04-14 00:00:00'), 'CVX'),
#        (Timestamp('2022-04-18 00:00:00'), 'AAPL'),
#        (Timestamp('2022-04-18 00:00:00'), 'CVX'),
#        (Timestamp('2022-04-19 00:00:00'), 'AAPL'),
#        (Timestamp('2022-04-19 00:00:00'), 'CVX'),
#        (Timestamp('2022-04-20 00:00:00'), 'AAPL'),
#        (Timestamp('2022-04-20 00:00:00'), 'CVX'),
#        (Timestamp('2022-04-21 00:00:00'), 'AAPL'),
#        (Timestamp('2022-04-21 00:00:00'), 'CVX'),
#        (Timestamp('2022-04-22 00:00:00'), 'AAPL'),
#        (Timestamp('2022-04-22 00:00:00'), 'CVX'),
#        (Timestamp('2022-04-25 00:00:00'), 'AAPL'),
#        (Timestamp('2022-04-25 00:00:00'), 'CVX'),
#        (Timestamp('2022-04-26 00:00:00'), 'AAPL'),
#        (Timestamp('2022-04-26 00:00:00'), 'CVX'),
#        (Timestamp('2022-04-27 00:00:00'), 'AAPL'),
#        (Timestamp('2022-04-27 00:00:00'), 'CVX'),
#        (Timestamp('2022-04-28 00:00:00'), 'AAPL'),
#        (Timestamp('2022-04-28 00:00:00'), 'CVX'),
#        (Timestamp('2022-04-29 00:00:00'), 'AAPL'),
#        (Timestamp('2022-04-29 00:00:00'), 'CVX'),
#        (Timestamp('2022-05-02 00:00:00'), 'AAPL'),
#        (Timestamp('2022-05-02 00:00:00'), 'CVX'),
#        (Timestamp('2022-05-03 00:00:00'), 'AAPL'),
#        (Timestamp('2022-05-03 00:00:00'), 'CVX'),
#        (Timestamp('2022-05-04 00:00:00'), 'AAPL'),
#        (Timestamp('2022-05-04 00:00:00'), 'CVX'),
#        (Timestamp('2022-05-05 00:00:00'), 'AAPL'),
#        (Timestamp('2022-05-05 00:00:00'), 'CVX'),
#        (Timestamp('2022-05-06 00:00:00'), 'AAPL'),
#        (Timestamp('2022-05-06 00:00:00'), 'CVX'),
#        (Timestamp('2022-05-09 00:00:00'), 'AAPL'),
#        (Timestamp('2022-05-09 00:00:00'), 'CVX'),
#        (Timestamp('2022-05-10 00:00:00'), 'AAPL'),
#        (Timestamp('2022-05-10 00:00:00'), 'CVX'),
#        (Timestamp('2022-05-11 00:00:00'), 'AAPL'),
#        (Timestamp('2022-05-11 00:00:00'), 'CVX'),
#        (Timestamp('2022-05-12 00:00:00'), 'AAPL'),
#        (Timestamp('2022-05-12 00:00:00'), 'CVX'),
#        (Timestamp('2022-05-13 00:00:00'), 'AAPL'),
#        (Timestamp('2022-05-13 00:00:00'), 'CVX'),
#        (Timestamp('2022-05-16 00:00:00'), 'AAPL'),
#        (Timestamp('2022-05-16 00:00:00'), 'CVX'),
#        (Timestamp('2022-05-17 00:00:00'), 'AAPL'),
#        (Timestamp('2022-05-17 00:00:00'), 'CVX'),
#        (Timestamp('2022-05-18 00:00:00'), 'AAPL'),
#        (Timestamp('2022-05-18 00:00:00'), 'CVX'),
#        (Timestamp('2022-05-19 00:00:00'), 'AAPL'),
#        (Timestamp('2022-05-19 00:00:00'), 'CVX'),
#        (Timestamp('2022-05-20 00:00:00'), 'AAPL'),
#        (Timestamp('2022-05-20 00:00:00'), 'CVX'),
#        (Timestamp('2022-05-23 00:00:00'), 'AAPL'),
#        (Timestamp('2022-05-23 00:00:00'), 'CVX'),
#        (Timestamp('2022-05-24 00:00:00'), 'AAPL'),
#        (Timestamp('2022-05-24 00:00:00'), 'CVX'),
#        (Timestamp('2022-05-25 00:00:00'), 'AAPL'),
#        (Timestamp('2022-05-25 00:00:00'), 'CVX'),
#        (Timestamp('2022-05-26 00:00:00'), 'AAPL'),
#        (Timestamp('2022-05-26 00:00:00'), 'CVX'),
#        (Timestamp('2022-05-27 00:00:00'), 'AAPL'),
#        (Timestamp('2022-05-27 00:00:00'), 'CVX'),
#        (Timestamp('2022-05-31 00:00:00'), 'AAPL'),
#        (Timestamp('2022-05-31 00:00:00'), 'CVX'),
#        (Timestamp('2022-06-01 00:00:00'), 'AAPL'),
#        (Timestamp('2022-06-01 00:00:00'), 'CVX'),
#        (Timestamp('2022-06-02 00:00:00'), 'AAPL'),
#        (Timestamp('2022-06-02 00:00:00'), 'CVX'),
#        (Timestamp('2022-06-03 00:00:00'), 'AAPL'),
#        (Timestamp('2022-06-03 00:00:00'), 'CVX')], dtype=object)
