# %% [markdown]
# # Interactive Stock Analysis
# The goal of this project is to provide code that will fetch data from finance site and, with the use of python code, parse through the data and re-format in a way that is easier to understand.

# %% [markdown]
# Importing Python packages

# %%
#Import pandas for functions and datareading
#Import MatplotLib for plotting
from pandas_datareader import data
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Function to provide financial data when called

# %%
def readmydata(tickers, start_date, end_date):
    financial_data = data.DataReader(tickers, 'yahoo', start_date, end_date)
    df = pd.DataFrame(financial_data)
    df.columns = df.columns
    output = df.stack(level=-1)
    return output
# Set 'Name' as the index of the dataframe

# %% [markdown]
# Calling function

# %%
readmydata(tickers=['AAPL', 'CVX'], start_date='2022-06-01', end_date='2022-08-05')
# Out:
# Attributes           Adj Close       Close        High         Low  \
# Date       Symbols
# 2022-06-01 AAPL     148.710007  148.710007  151.740005  147.679993
#            CVX      176.320007  176.320007  178.130005  174.940002
# 2022-06-02 AAPL     151.210007  151.210007  151.270004  146.860001
#            CVX      176.000000  176.000000  176.509995  174.100006
# 2022-06-03 AAPL     145.380005  145.380005  147.970001  144.460007
#            CVX      177.600006  177.600006  178.250000  176.000000
# 2022-06-06 AAPL     146.139999  146.139999  148.570007  144.899994
#            CVX      176.830002  176.830002  178.000000  175.509995
# 2022-06-07 AAPL     148.710007  148.710007  149.000000  144.100006
#            CVX      180.199997  180.199997  180.660004  176.919998
# 2022-06-08 AAPL     147.960007  147.960007  149.869995  147.460007
#            CVX      181.130005  181.130005  182.399994  180.250000
# 2022-06-09 AAPL     142.639999  142.639999  147.949997  142.529999
# ...

# %% [markdown]
# Function takes as input dataframe and picks columns

# %%
def pickmydata(Attributes):
    output = readmydata(tickers=['AAPL', 'CVX'], start_date='2022-06-01', end_date='2022-08-05')[Attributes]
    output
    
    #Object series indexed by date
    tickers = close.loc[:, 'AAPL' 'CVX']
    
    #20-day moving average
    short_rolling_tickers = tickers.rolling(window=20).mean()
    
    #Plot
    fig, ax = plt.subplots(figsize=(16,9))
    ax.plot(tickers.index, tickers, label=tickers)
    ax.plot(short_rolling_tickers.index, short_rolling_tickers, label='20 days rolling')
    ax.set_xlabel('Date')
    ax.set_ylabel('Adjusted ' + Attributes + ' Price ($)')
    ax.legend()
    return output.describe()

# %%
pickmydata("Close")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'AAPLCVX'
#
# The above exception was the direct cause of the following exception:
#
# ...
